# %% [markdown]
# Some ideas for the project:
# - Since 1980 what other crises/events may have impacted unemployment in the U.S. as much as the COVID pandemic (data from 2020)?
# - Have there been any other crises that have had as much effect?
# - Do men and women, different demographic groups and/or employment sectors get affected differently in terms of the impact on unemployment during COVID and other crises/events?
# Suggested by JR:
# - Look at new jobs booming, high tech jobs, teaching, coding, home health(noom, fitness+), telehealth, virtual solutions, ppe, lysol, toilet paper - not sure we can do these, nor that they would be useful to include. Not enough time?
# - How many people were let go, which industries got impacted the most. Which states were affected most because of their prevalent industries - again, not within our scope.
# - How are different states faring based on their policies in 2020? - not within our scope.
# - State reported numbers artificially high or low - no way to know this.
# - Who made the money? Big Pharma, Ecommerce, 18 of the richest families tripling their incomes - not within our scope
# - Cyber attacks( is it a coordinated effort, biological weapons) - not within our scope.

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
pd.set_option('display.max_rows', 900)
pd.set_option('display.max_columns', None)
import seaborn as sns

# %% [markdown]
# # Import csv files

# %%
unrate_all = pd.read_csv("UNRATE_NSA.csv")
unrate_all
# Out:
#            DATE  UNRATENSA
# 0    1948-01-01        4.0
# 1    1948-02-01        4.7
# 2    1948-03-01        4.5
# 3    1948-04-01        4.0
# 4    1948-05-01        3.4
# 5    1948-06-01        3.9
# 6    1948-07-01        3.9
# 7    1948-08-01        3.6
# 8    1948-09-01        3.4
# 9    1948-10-01        2.9
# 10   1948-11-01        3.3
# 11   1948-12-01        3.6
# 12   1949-01-01        5.0
# 13   1949-02-01        5.8
# 14   1949-03-01        5.6
# 15   1949-04-01        5.4
# 16   1949-05-01        5.7
# 17   1949-06-01        6.4
# 18   1949-07-01        7.0
# 19   1949-08-01        6.3
# 20   1949-09-01        5.9
# 21   1949-10-01        6.1
# 22   1949-11-01        5.7
# 23   1949-12-01        6.0
# 24   1950-01-01        7.6
# 25   1950-02-01        7.9
# 26   1950-03-01        7.1
# 27   1950-04-01        6.0
# 28   1950-05-01        5.3
# 29   1950-06-01        5.6
# 30   1950-07-01        5.3
# 31   1950-08-01        4.1
# 32   1950-09-01        4.0
# ...

# %% [markdown]
# # When you download CSV's from https://fred.stlouisfed.org/, the file names are surrogate keys so change them to UNRATE_WOMEN.csv, UNRATE_MEN.csv, etc.

# %%
#add variables for each demographic/industry and change number at the end to how many demographic/industries
[unrate_women, unrate_men, unrate_aa, unrate_latino, unrate_white, unrate_asian, unrate_agr, unrate_cnstrct, unrate_lsr_hspt, 
unrate_mnfct, unrate_ed_hlth_svces, unrate_farm_fish_forest, unrate_fin, unrate_info, unrate_mgmt_fin_ops, unrate_mining_etc, 
unrate_natres_maint, unrate_office_admin, unrate_pro, unrate_pro_bus, unrate_prod, unrate_sales, unrate_self, unrate_svce, 
unrate_transp_util, unrate_whlsl_rtl] = [""] * 26

#follow this format with additional demographics/industries
features = [[unrate_women,"UNRATE_WOMEN.csv"], [unrate_men, "UNRATE_MEN.csv"], [unrate_aa,"UNRATE_AA.csv"], 
            [unrate_latino,"UNRATE_LATINO.csv"], [unrate_white, "UNRATE_WHITE.csv"],  [unrate_asian, "UNRATE_ASIAN.csv"],
            #Industries!
            [unrate_agr, 'UNRATE_AGR.csv'], [unrate_cnstrct, 'UNRATE_CNSTRCT.csv'], [unrate_lsr_hspt, 'UNRATE_LSR_HSPT.csv'], 
            [unrate_mnfct, 'UNRATE_MNFCT.csv'], [unrate_ed_hlth_svces, 'UNRATE_ED_HLTH_SVCES.csv'], 
            [unrate_farm_fish_forest, 'UNRATE_FARM_FISH_FOREST.csv'], [unrate_fin, 'UNRATE_FIN.csv'], 
            [unrate_info, 'UNRATE_INFO.csv'], [unrate_mgmt_fin_ops, 'UNRATE_MGMT_FIN_OPS.csv'], 
            [unrate_mining_etc, 'UNRATE_MINING_ETC.csv'], [unrate_natres_maint, 'UNRATE_NATRES_MAINT.csv'], 
            [unrate_office_admin, 'UNRATE_OFFICE_ADMIN.csv'], [unrate_pro, 'UNRATE_PRO.csv'], 
            [unrate_pro_bus, 'UNRATE_PRO_BUS.csv'], [unrate_prod, 'UNRATE_PROD.csv'], [unrate_sales, 'UNRATE_SALES.csv'], 
            [unrate_self, 'UNRATE_SELF.csv'], [unrate_svce, 'UNRATE_SVCE.csv'], [unrate_transp_util, 'UNRATE_TRANSP_UTIL.csv'], 
            [unrate_whlsl_rtl, 'UNRATE_WHLSL_RTL.csv']]

# %%
for index in range(len(features)):
    features[index][0] = pd.read_csv(features[index][1])
    features[index][0] = features[index][0].rename(columns = {features[index][0].columns[1]: features[index][1][:-4]})
    unrate_all = pd.merge(unrate_all, features[index][0], how="outer")

# %% [markdown]
# # How many values can we include? Check nulls.

# %%
unrate_all.isnull().sum()
# Out:
# DATE                         0
# UNRATENSA                    0
# UNRATE_WOMEN                 0
# UNRATE_MEN                   0
# UNRATE_AA                  288
# UNRATE_LATINO              302
# UNRATE_WHITE                72
# UNRATE_ASIAN               624
# UNRATE_AGR                 624
# UNRATE_CNSTRCT             624
# UNRATE_LSR_HSPT            624
# UNRATE_MNFCT               624
# UNRATE_ED_HLTH_SVCES       624
# UNRATE_FARM_FISH_FOREST    624
# UNRATE_FIN                 624
# UNRATE_INFO                624
# UNRATE_MGMT_FIN_OPS        624
# UNRATE_MINING_ETC          624
# UNRATE_NATRES_MAINT        624
# UNRATE_OFFICE_ADMIN        624
# UNRATE_PRO                 624
# UNRATE_PRO_BUS             624
# UNRATE_PROD                624
# UNRATE_SALES               624
# UNRATE_SELF                624
# UNRATE_SVCE                624
# UNRATE_TRANSP_UTIL         624
# UNRATE_WHLSL_RTL           624
# dtype: int64

# %% [markdown]
# # Isolate dataset

# %%
unrate_all.iloc[624:,:] #Rows 624 and above, All columns
# Out:
#            DATE  UNRATENSA  UNRATE_WOMEN  UNRATE_MEN  UNRATE_AA  \
# 624  2000-01-01        4.5           4.3         4.6        8.3
# 625  2000-02-01        4.4           4.2         4.7        8.3
# 626  2000-03-01        4.3           4.3         4.3        7.4
# 627  2000-04-01        3.7           3.7         3.7        6.5
# 628  2000-05-01        3.8           4.1         3.6        7.6
# 629  2000-06-01        4.1           4.5         3.9        8.0
# 630  2000-07-01        4.2           4.6         3.8        8.5
# 631  2000-08-01        4.1           4.6         3.6        8.1
# 632  2000-09-01        3.8           4.1         3.5        7.1
# 633  2000-10-01        3.6           3.7         3.5        7.0
# 634  2000-11-01        3.7           3.8         3.7        7.1
# 635  2000-12-01        3.7           3.4         4.0        6.9
# 636  2001-01-01        4.7           4.3         5.0        8.4
# 637  2001-02-01        4.6           4.2         4.9        7.9
# ...

# %%
unrate_all['DATE'] = pd.to_datetime(unrate_all['DATE'])

# %% [markdown]
# # Create a data frame that has month and year as features

# %%
unrate_all_date = unrate_all.copy()
unrate_all_date['YEAR'] = unrate_all_date['DATE'].dt.year
unrate_all_date["MONTH"]= unrate_all_date['DATE'].dt.month

# %% [markdown]
# # Reorder Columns

# %%
unrate_all_date = unrate_all_date.reindex(columns = ['DATE', 'YEAR', 'MONTH', 'UNRATENSA', 'UNRATE_WOMEN', 'UNRATE_MEN', 
                                                     'UNRATE_AA','UNRATE_LATINO', 'UNRATE_WHITE', 'UNRATE_ASIAN', 
                                                     'UNRATE_AGR','UNRATE_CNSTRCT', 'UNRATE_LSR_HSPT', 'UNRATE_MNFCT', 
                                                     'UNRATE_ED_HLTH_SVCES', 'UNRATE_FARM_FISH_FOREST', 'UNRATE_FIN', 
                                                     'UNRATE_INFO', 'UNRATE_MGMT_FIN_OPS', 'UNRATE_MINING_ETC', 
                                                     'UNRATE_NATRES_MAINT', 'UNRATE_OFFICE_ADMIN', 'UNRATE_PRO', 
                                                     'UNRATE_PRO_BUS', 'UNRATE_PROD', 'UNRATE_SALES', 'UNRATE_SELF', 
                                                     'UNRATE_SVCE', 'UNRATE_TRANSP_UTIL', 'UNRATE_WHLSL_RTL'])

# %% [markdown]
# # Men vs Women

# %%
men_and_women = unrate_all_date[['YEAR', "UNRATENSA", "UNRATE_MEN", "UNRATE_WOMEN"]].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(men_and_women, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %% [markdown]
# ## Five of eleven events have women above the national average, four of eleven events have men above the national average.

# %% [markdown]
# # Ethnicity/Race

# %%
ethnicity_race = unrate_all_date[['YEAR', "UNRATENSA", "UNRATE_AA", "UNRATE_LATINO", "UNRATE_WHITE", 
                                  "UNRATE_ASIAN"]].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(ethnicity_race, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %% [markdown]
# ## AA and Latino are always above the national average in the window seen here.

# %% [markdown]
# # By Sector

# %%
sector = unrate_all_date[['YEAR', 'UNRATE_AGR','UNRATE_CNSTRCT', 'UNRATE_LSR_HSPT', 'UNRATE_MNFCT', 
                                                     'UNRATE_ED_HLTH_SVCES', 'UNRATE_FARM_FISH_FOREST', 'UNRATE_FIN', 
                                                     'UNRATE_INFO', 'UNRATE_MGMT_FIN_OPS', 'UNRATE_MINING_ETC', 
                                                     'UNRATE_NATRES_MAINT', 'UNRATE_OFFICE_ADMIN', 'UNRATE_PRO', 
                                                     'UNRATE_PRO_BUS', 'UNRATE_PROD', 'UNRATE_SALES', 'UNRATE_SELF', 
                                                     'UNRATE_SVCE', 'UNRATE_TRANSP_UTIL', 'UNRATE_WHLSL_RTL']].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(sector, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %% [markdown]
# ## This is very busy; need to tease out the threads, and/or collapse some sectors together. Also does not include UNRATE_NSA yet.

# %%
unrate_all_date.loc[unrate_all_date["DATE"] >= "2000-01-01"]
# Out:
#           DATE  YEAR  MONTH  UNRATENSA  UNRATE_WOMEN  UNRATE_MEN  UNRATE_AA  \
# 624 2000-01-01  2000      1        4.5           4.3         4.6        8.3
# 625 2000-02-01  2000      2        4.4           4.2         4.7        8.3
# 626 2000-03-01  2000      3        4.3           4.3         4.3        7.4
# 627 2000-04-01  2000      4        3.7           3.7         3.7        6.5
# 628 2000-05-01  2000      5        3.8           4.1         3.6        7.6
# 629 2000-06-01  2000      6        4.1           4.5         3.9        8.0
# 630 2000-07-01  2000      7        4.2           4.6         3.8        8.5
# 631 2000-08-01  2000      8        4.1           4.6         3.6        8.1
# 632 2000-09-01  2000      9        3.8           4.1         3.5        7.1
# 633 2000-10-01  2000     10        3.6           3.7         3.5        7.0
# 634 2000-11-01  2000     11        3.7           3.8         3.7        7.1
# ...

# %%
sector = unrate_all_date[['YEAR', 'UNRATE_AGR', 'UNRATENSA']].iloc[624:,:].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(sector, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %%
sector = unrate_all_date[['YEAR', 'UNRATE_CNSTRCT', 'UNRATENSA']].iloc[624:,:].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(sector, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %%
sector = unrate_all_date[['YEAR', 'UNRATE_OFFICE_ADMIN', 'UNRATENSA', 'UNRATE_WOMEN']].iloc[624:,:].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(sector, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %%
sector = unrate_all_date[['YEAR', 'UNRATE_ED_HLTH_SVCES', 'UNRATENSA']].iloc[624:,:].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(sector, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %%
sector = unrate_all_date[['YEAR', 'UNRATE_SALES', 'UNRATENSA']].iloc[624:,:].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(sector, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %%
sector = unrate_all_date[['YEAR', 'UNRATE_PRO_BUS', 'UNRATENSA']].iloc[624:,:].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(sector, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %%
sector = unrate_all_date[['YEAR', 'UNRATE_FIN', 'UNRATENSA']].iloc[624:,:].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(sector, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %%
sector = unrate_all_date[['YEAR', 'UNRATE_SELF', 'UNRATENSA']].iloc[624:,:].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(sector, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %%
sector = unrate_all_date[['YEAR', 'UNRATE_INFO', 'UNRATENSA']].iloc[624:,:].groupby("YEAR").mean().reset_index()
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(x='YEAR', y='value', hue='variable', 
             data=pd.melt(sector, ['YEAR']))
# Out:
# <AxesSubplot:xlabel='YEAR', ylabel='value'>

# %% [markdown]
# # Once you have final dataframe you can export to CSV

# %%
unrate_all.to_csv("unrate_all.csv")

# %%
import seaborn as sns
sns.heatmap(unrate_all.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## AGR, FARM_FISH_FOREST, and MINING do not correlate well to anything else.
